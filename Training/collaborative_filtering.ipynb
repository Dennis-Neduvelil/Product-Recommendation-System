# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv('../input/pivot-table-transactions/pivot_table_transactions.csv',)
df.info()

# %%
from sklearn.metrics.pairwise import cosine_similarity as cs
similarity=cs(df)

# %%
similarity.nbytes

# %%
similarity = similarity.astype('float16')
print('completed')

# %%
similarity.nbytes

# %%
sorted(list(enumerate(similarity[0])),key=lambda x:x[1],reverse=True)[0:20]

# %%
def reccomend(product_id):
    index=np.where(df.Products==product_id)[0][0]
    similar_items = sorted(list(enumerate(similarity[0])),key=lambda x:x[1],reverse=True)[0:20]
    for i in similar_items:
        print(df.Products[i[0]])

# %%
reccomend(1163)

# %%
import pickle
pickle.dump(similarity,open('collabrative_filtering_model.pkl','wb'),protocol=4)
print('File Saved')
